# %% [markdown]
# ## Az előző részek tartalmából...

# %%
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
from selenium.common.exceptions import NoSuchElementException


options = Options()
options.headless = False
DRIVER = webdriver.Chrome(options=options, executable_path="../selenium_driver/chromedriver")

# %% [markdown]
# ## Látogassunk el a Jófogás.hu ingatlanok hirdetésével foglalkozó oldalára!

# %%
DRIVER.get("https://ingatlan.jofogas.hu/magyarorszag/ingatlan?st=s")

# %% [markdown]
# Majd nyissuk meg az oldal forrás html-jét, hogy pontos információt kapjunk az oldal elemeiről!
# ### Seleniummal több módja is van az oldalon történő keresésnek:
# #### Lehetőségünk van egyéni WebElementek gyűjtésére például az 'id' attribute segítségével:

# %%
my_element = DRIVER.find_element_by_id("listid_110752612")
print(f"Scraped WebElement: {my_element}")
print(f"Text: \n{my_element.text}")
# Out:
# Scraped WebElement: <selenium.webdriver.remote.webelement.WebElement (session="d63d71f5566a8dd647086375031b970e", element="eec8cae0-2095-48d3-8067-c640a5e0239f")>
# Text:
# 150 nm-es ház eladó Siófok
# 13
# 26 500 000  Ft
# 150 m² 1 szoba 176 666 Ft/m²
# Somogy , Siófok
# Céges

# %% [markdown]
# #### Vagy egy közös attribute-tal (pl. ugyanolyan 'class') WebElementek listáját elérni:

# %%
contentArea_class_elements = DRIVER.find_elements_by_class_name("contentArea")
print(f"Number of elements with class='contentArea': {len(contentArea_class_elements)}")
print(f"List of WebElements, with class='contentArea': \n{contentArea_class_elements}")
# Out:
# Number of elements with class='contentArea': 25
# List of WebElements, with class='contentArea':
# [<selenium.webdriver.remote.webelement.WebElement (session="d63d71f5566a8dd647086375031b970e", element="be34b415-287b-44e4-a811-9fca0747ffc8")>, <selenium.webdriver.remote.webelement.WebElement (session="d63d71f5566a8dd647086375031b970e", element="2c54b76f-82ee-4f90-a5b2-511755a249d9")>, <selenium.webdriver.remote.webelement.WebElement (session="d63d71f5566a8dd647086375031b970e", element="725c1a7d-b790-4fa5-bc2b-7ae5007fec95")>, <selenium.webdriver.remote.webelement.WebElement (session="d63d71f5566a8dd647086375031b970e", element="ccc404d4-478d-458c-909a-fdc43751041a")>, <selenium.webdriver.remote.webelement.WebElement (session="d63d71f5566a8dd647086375031b970e", element="6a65cc5c-e1ba-49aa-8229-c02fb63af0ab")>, <selenium.webdriver.remote.webelement.WebElement (session="d63d71f5566a8dd647086375031b970e", element="ee1bd0ab-b6e1-426b-8e79-23b2a62996dc")>, <selenium.webdriver.remote.webelement.WebElement (session="d63d71f5566a8dd647086375031b970e", element="1dbfa25e-9864-4cc4-95b7-14d34446ee01")>, <selenium.webdriver.remote.webelement.WebElement (session="d63d71f5566a8dd647086375031b970e", element="a129372f-4a89-40ab-85b1-5d930419610b")>, <selenium.webdriver.remote.webelement.WebElement (session="d63d71f5566a8dd647086375031b970e", element="68085579-9ecc-4063-8399-9c7cce7c1478")>, <selenium.webdriver.remote.webelement.WebElement (session="d63d71f5566a8dd647086375031b970e", element="34881368-c924-4293-8f14-55a02445933b")>, <selenium.webdriver.remote.webelement.WebElement (session="d63d71f5566a8dd647086375031b970e", element="8ea3959d-5765-417e-91e9-00422d705be7")>, <selenium.webdriver.remote.webelement.WebElement (session="d63d71f5566a8dd647086375031b970e", element="9824ecb1-5eb1-410b-9e1a-56e66f53cc7f")>, <selenium.webdriver.remote.webelement.WebElement (session="d63d71f5566a8dd647086375031b970e", element="91203bf1-6990-4147-8334-3f4e9fd6d313")>, <selenium.webdriver.remote.webelement.WebElement (session="d63d71f5566a8dd647086375031b970e", element="c816f9f8-2754-4e0f-9f8f-bfd5e8762ac2")>, <selenium.webdriver.remote.webelement.WebElement (session="d63d71f5566a8dd647086375031b970e", element="74897c60-48a2-4751-a605-4b2eea71249d")>, <selenium.webdriver.remote.webelement.WebElement (session="d63d71f5566a8dd647086375031b970e", element="407af16d-7e5b-44e0-acc1-31e1263f8ca3")>, <selenium.webdriver.remote.webelement.WebElement (session="d63d71f5566a8dd647086375031b970e", element="a4883500-e10a-4b73-b977-899858b6780e")>, <selenium.webdriver.remote.webelement.WebElement (session="d63d71f5566a8dd647086375031b970e", element="feb3a173-4606-44d0-97db-e0a351f0ae22")>, <selenium.webdriver.remote.webelement.WebElement (session="d63d71f5566a8dd647086375031b970e", element="676d9524-801c-4c0c-875a-65140f2d4744")>, <selenium.webdriver.remote.webelement.WebElement (session="d63d71f5566a8dd647086375031b970e", element="f95fe14c-384c-4b30-b43f-7c610eeda456")>, <selenium.webdriver.remote.webelement.WebElement (session="d63d71f5566a8dd647086375031b970e", element="a7fd24c7-f92e-4cda-ab3f-89141a4d3534")>, <selenium.webdriver.remote.webelement.WebElement (session="d63d71f5566a8dd647086375031b970e", element="9ae8ec03-cba2-4db6-b985-5f268b7a00d8")>, <selenium.webdriver.remote.webelement.WebElement (session="d63d71f5566a8dd647086375031b970e", element="92647d13-0b43-4835-b3e7-29d16df88853")>, <selenium.webdriver.remote.webelement.WebElement (session="d63d71f5566a8dd647086375031b970e", element="ac3e7bf5-9f43-4671-8fef-056955d874ce")>, <selenium.webdriver.remote.webelement.WebElement (session="d63d71f5566a8dd647086375031b970e", element="e777a534-27e5-4647-9983-14fa6a73e3ce")>]

# %% [markdown]
# #### Ennek elemeit akár egyesével is el lehet érni:

# %%
first_conentArea_class_element = contentArea_class_elements[0]
print(f"Scraped WebElement: {my_element}")
print(f"Text: \n{contentArea_class_elements[0].text}")
# Out:
# Scraped WebElement: <selenium.webdriver.remote.webelement.WebElement (session="d63d71f5566a8dd647086375031b970e", element="eec8cae0-2095-48d3-8067-c640a5e0239f")>
# Text:
# 150 nm-es ház eladó Siófok
# 13
# 26 500 000  Ft
# 150 m² 1 szoba 176 666 Ft/m²
# Somogy , Siófok
# Céges

# %% [markdown]
# # XPATH
# Előbb-utóbb látni fogjuk, hogy ezek az attribute-alapú függvények eléggé limitáltak és komplexebb (vagy csak simán igénytelen) oldalakon már nem lesznek elegek.
# ## Mi is az XPATH?
# Az "XML Path Language" rövidítése, mely egy olyan nyelvet takar ami egy "út szerű" szintaktikát használva navigál az oldal (vagy xml) elemei (node-ok) között.
# ### Az előző contentArea class-os dolog megvalósítása XPATH-el:

# %%
cAces_by_xpath = DRIVER.find_elements_by_xpath("//div[@class='contentArea']")
print(f"Number of elements with class='contentArea': {len(cAces_by_xpath)}")
fcAce_by_xpath = cAces_by_xpath[0]
print(f"Text of first:\n{fcAce_by_xpath.text}")
# Out:
# Number of elements with class='contentArea': 25
# Text of first:
# 150 nm-es ház eladó Siófok
# 13
# 26 500 000  Ft
# 150 m² 1 szoba 176 666 Ft/m²
# Somogy , Siófok
# Céges

# %% [markdown]
# ## Felépítése:
#         //div[@class='contentArea']
# ### "//", "/"
# ROOT: Keresés kiinduló nodeja/elementje. Ha nincsen megadva semmi a html dokumentum-ot veszi annak.
# - //: az útvonal relatív - tehát "Keress a ROOT-ból belül bárhol egy olyan divet ahol ..."
# - /: &nbsp;az útvonal direkt - tehát "Keress a ROOT közvetlen gyerek-elementje között olyat, ahol ..."
#
# ### div (vagy bármely más html element)
# A keresett element típusa. Ha láncoljuk az XPATH-t, az utolsó.
#
# ### \[@attribute='restriction'\]
# - \[\]-el jelöljük, ha az előző element valamelyik tulajdonságá szerint szeretnénk szűkíteni a keresést.
# - @attribute: A tulajdonság neve "@" jel után.
# - 'restriction': ''-ök között a tulajdonság megkötése.

# %%
offer_sections_in_content_area = DRIVER.find_elements_by_xpath("//div[@class='contentArea']/section[@itemprop='offers']")
print("Offers:\n")
for offer in offer_sections_in_content_area:
    print(offer.text)
# Out:
# Offers:
#
# 26 500 000  Ft
# 380 000 000  Ft
# 39 900 000  Ft
# 12 500 000  Ft
# 35 900 000  Ft
# 11 500 000  Ft
# 15 000 000  Ft
# 7 500 000  Ft
# 28 900 000  Ft
# 15 500 000  Ft
# 38 900 000  Ft
# 39 000 000  Ft
# 32 500 000  Ft
# 34 900 000  Ft
# 25 500 000  Ft
# 26 800 000  Ft
# 32 990 000  Ft
# 20 900 000  Ft
# 99 800 000  Ft
# 22 200 000  Ft
# 85 000 000  Ft
# 26 000 000  Ft
# 8 900 000  Ft
# 41 900 000  Ft
# 129 000 000  Ft

# %% [markdown]
# ### Itt egy utat írtunk le, ami:
# &nbsp;&nbsp;olyan **<section\>**-öket fog keresni<br>&nbsp;&nbsp;az oldal **<div class="contentArea"\>** element-jeinek<br>&nbsp;&nbsp;&nbsp;&nbsp;**elsőfokú gyerek**-elementjei között,<br>&nbsp;&nbsp;melyeknek az **itemprop attribútumának értéke "offers"**.

# %%
first_offer_section = offer_sections_in_content_area[0]
price_value_span = first_offer_section.find_element_by_xpath(".//span[contains(@class,'price')]")
currency_span = price_value_span.find_element_by_xpath("(./following-sibling::span)[1]")

# %% [markdown]
# ### Itt az előző elementet vettük kiindulási pontnak (ROOT):
# #### "/" és "//" helyett "./"-t és ".//"-t használunk!
# Ezzel jelezzük, hogy nem az HTML-DOCUMENT, hanem a változóban tárolt WebElement a ROOT-ja a következő XPATH-nek.
# #### Keresési függvény (szerűség?).
# A \[\]-eken belül különböző XPATH függvényeket is meghívhatunk a saját szintaktikájukkal. A contains például egy szövegrészletet keres a megadott attribútum értékében.<br>
# Ha az előtte álló XPATH-t \(\)-kel kijelöljük, listaként kezelve lekérhetjük n-edik adattagját. XPATH-ben 0, helyett 1 az első index!
# #### element_A/following-sibling::elementType
# A HTML hard-code-ban az element_A-t követő, az ő globális szintjén lévő (pl.: HTML-DOC ROOT-tól számítva minden harmad-fokú gyerek) elementType típusú objektumok listája.

# %%
first_price = {}
first_price["value"] = int(price_value_span.text.replace(" ", ""))
first_price["currency"] = currency_span.text.replace(" ", "")
print(first_price)
# Out:
# {'value': 26500000, 'currency': 'Ft'}

# %% [markdown]
# ### Oldalak között válthatunk úgy, hogy megkeressük a következő page-url-t tartalmazó objektumot és átadjuk a href attribútumát a DRIVER.get()-nek:

# %%
next_page_link = DRIVER.find_element_by_xpath("//a[contains(@class,'jofogasicon-right')]")
next_url = next_page_link.get_attribute("href")
print(f"Going to: {next_url}")
DRIVER.get(next_url)
# Out:
# Going to: https://ingatlan.jofogas.hu/magyarorszag/ingatlan?st=s&o=2

# %% [markdown]
# ### Vagy egyszerűen kattintsunk a linket tartalmazó objektumra:

# %%
next_page_link = DRIVER.find_element_by_xpath("//a[contains(@class,'jofogasicon-right')]")
print("Clicking next button")
DRIVER.execute_script("arguments[0].click();", next_page_link)
# Out:
# Clicking next button

# %%
DRIVER.close()
